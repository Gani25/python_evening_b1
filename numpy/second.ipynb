# %% [markdown]
# # More On Numpy

# %%
import numpy as np

# %%
arr = np.array([5,1,7,9,3])
arr
# Out:
# array([5, 1, 7, 9, 3])

# %%
arr.ndim
# Out:
# 1

# %%
arr.shape
# Out:
# (5,)

# %%
arr = np.array([
    [20,60,-6,45],
    [10,8,6,44],
    [115,82,-66,-344],
    [41,32,-86,-411],
    [15,2,6,-4],
    [1105,802,-660,-3404],
])
arr
# Out:
# array([[   20,    60,    -6,    45],
#        [   10,     8,     6,    44],
#        [  115,    82,   -66,  -344],
#        [   41,    32,   -86,  -411],
#        [   15,     2,     6,    -4],
#        [ 1105,   802,  -660, -3404]])

# %%
arr.ndim
# Out:
# 2

# %%
arr.shape
# Out:
# (6, 4)

# %% [markdown]
# ## Slicing

# %%
arr
# Out:
# array([[   20,    60,    -6,    45],
#        [   10,     8,     6,    44],
#        [  115,    82,   -66,  -344],
#        [   41,    32,   -86,  -411],
#        [   15,     2,     6,    -4],
#        [ 1105,   802,  -660, -3404]])

# %%
print(arr[3,2])
# Out:
# -86

# %%
arr[3,2]
# Out:
# np.int64(-86)

# %%
arr
# Out:
# array([[   20,    60,    -6,    45],
#        [   10,     8,     6,    44],
#        [  115,    82,   -66,  -344],
#        [   41,    32,   -86,  -411],
#        [   15,     2,     6,    -4],
#        [ 1105,   802,  -660, -3404]])

# %%
arr[2:4]
# Out:
# array([[ 115,   82,  -66, -344],
#        [  41,   32,  -86, -411]])

# %%
arr[2:4,1:3]
# Out:
# array([[ 82, -66],
#        [ 32, -86]])
