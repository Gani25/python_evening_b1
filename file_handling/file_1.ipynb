# %% [markdown]
# # Intro To Markdown

# %% [markdown]
# [LinkedIn](https://www.linkedin.com/in/memon-abdul-gani/)

# %% [markdown]
# **Table**

# %% [markdown]
# ---

# %%
print("Hello")
# Out:
# Hello

# %%
f = open("student.txt","r")

print(f.read())

f.close()
# Out:
# 1 Shruti Shinde Female
# 2 Rohini Chavan Female
# 3 Ashish Verma Male
# 4 Saurabh Gupyta Male

# %%
with open("student.txt","r") as f:
    print(f.read())
# Out:
# 1 Shruti Shinde Female
# 2 Rohini Chavan Female
# 3 Ashish Verma Male
# 4 Saurabh Gupyta Male

# %%
with open("student.txt","r") as f:
    for line in f:
        print(f"Line = {line}")
# Out:
# Line = 1 Shruti Shinde Female
#
# Line = 2 Rohini Chavan Female
#
# Line = 3 Ashish Verma Male
#
# Line = 4 Saurabh Gupyta Male

# %%
with open("student.txt","r") as f:
    print(f.readlines())
# Out:
# ['1 Shruti Shinde Female\n', '2 Rohini Chavan Female\n', '3 Ashish Verma Male\n', '4 Saurabh Gupyta Male']
